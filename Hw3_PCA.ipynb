# %%
import os
os.getcwd()
# Out:
# 'C:\\Projects\\Python\\Kodluyoruz\\Hw\\assignment-BerkeAtalay'

# %%
from Process_Classes import information, models

# %%
df = information("data/","HW_Data_Set.xlsx")
# Out:
# Class object initialized

# %%
df.get_inf(True,"drop")
# Out:
# HW_Data_Set.xlsx is loaded
# 6167
# 6167
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...  ind_416  ind_418  ind_420  ind_422  ind_424   ind_426  \
# 0   17.62   11.73  ...    -49.6      -54     -152     -353      1.0  0.498547
# 1   18.16   12.22  ...    -55.6      -60     -158     -359      1.0  0.537088
# 2   17.86   12.28  ...    -58.4      -60     -160     -362      1.0  0.615169
# 3   14.76   12.61  ...    -61.8      -65     -166     -367      1.0  0.661517
# 4   11.92   14.25  ...    -79.8      -86     -186     -388      1.0  0.747204
#
# ...

# %%
df.catinfo()
# Out:
#   ind_109 ind_420 ind_422
# 0   GREEN    -152    -353
# 1   GREEN    -158    -359
# 2   GREEN    -160    -362
# 3   GREEN    -166    -367
# 4   GREEN    -186    -388

# %%
df.dropcolumn(["ind_420","ind_422"])

# %%
df.get_inf(False)
# Out:
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...   ind_412  ind_414  ind_416  ind_418  ind_424  \
# 0   17.62   11.73  ...  0.002371      2.0    -49.6      -54      1.0
# 1   18.16   12.22  ...  0.003074      0.8    -55.6      -60      1.0
# 2   17.86   12.28  ...  0.003561      2.7    -58.4      -60      1.0
# 3   14.76   12.61  ...  0.004366      0.9    -61.8      -65      1.0
# 4   11.92   14.25  ...  0.004198      0.1    -79.8      -86      1.0
#
#     ind_426   ind_428  20_target  50_target  90_target
# ...

# %%
df.catinfo()
# Out:
#   ind_109
# 0   GREEN
# 1   GREEN
# 2   GREEN
# 3   GREEN
# 4   GREEN

# %%
df.cattodummy()
# Out:
# Looking for: ['ind_109']
# Adding columns:  ['ind_109_GREEN', 'ind_109_RED']
# Dummies entered as .catdata
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...  ind_416  ind_418  ind_424   ind_426   ind_428  \
# 0   17.62   11.73  ...    -49.6      -54      1.0  0.498547  0.701906
# 1   18.16   12.22  ...    -55.6      -60      1.0  0.537088  0.690833
# 2   17.86   12.28  ...    -58.4      -60      1.0  0.615169  0.693040
# 3   14.76   12.61  ...    -61.8      -65      1.0  0.661517  0.673418
# ...

# %%
df.dropcolumn(["20_target","90_target"])

# %%
y,X= df.choose_your_y("50_target")
# Out:
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...  ind_410   ind_412  ind_414  ind_416  ind_418  ind_424  \
# 0   17.62   11.73  ...      -27  0.002371      2.0    -49.6      -54      1.0
# 1   18.16   12.22  ...      -31  0.003074      0.8    -55.6      -60      1.0
# 2   17.86   12.28  ...      -30  0.003561      2.7    -58.4      -60      1.0
# 3   14.76   12.61  ...      -30  0.004366      0.9    -61.8      -65      1.0
# 4   11.92   14.25  ...      -45  0.004198      0.1    -79.8      -86      1.0
#
# ...

# %%
X = X.drop("ind_109_RED",axis=1)

# %%
from sklearn.feature_selection import VarianceThreshold
correlated_features = set()
correlation_matrix = X.corr()

# %%
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.95:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)

# %%
len(correlated_features)
# Out:
# 31

# %%
print(correlated_features)
# Out:
# {'ind_51', 'ind_102', 'ind_46', 'ind_407', 'ind_243', 'ind_32', 'ind_387', 'ind_136', 'ind_67', 'ind_153', 'ind_20', 'ind_6', 'ind_313', 'ind_70', 'ind_410', 'ind_234', 'ind_21', 'ind_404', 'ind_318', 'ind_406', 'ind_48', 'ind_150', 'ind_19', 'ind_118', 'ind_128', 'ind_130', 'ind_34', 'ind_132', 'ind_92', 'ind_49', 'ind_35'}

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
len(X.T)
# Out:
# 100

# %%
md = models(X,y)
# Out:
# Model class 42

# %%
md.model_selection("pca")
# Out:
# PCA is initilialized without specific number of components

# %%
md.pca_proc()
# Out:
# Pca sonrası değişken sayısı:  17
# New X_train values are saved as X_train_pcad

# %%
md.X_train_pcad.index
# Out:
# Int64Index([6066, 3710, 5095, 5427,  344, 2728,  911, 4855,   47, 4419,
#             ...
#             4426, 5334,  466, 5734, 3092, 3772, 5191, 5226, 5390,  860],
#            dtype='int64', length=4933)

# %%
md.y_train
# Out:
# 6066    34.207370
# 3710   -36.539031
# 5095    34.405104
# 5427    34.741962
# 344     35.351444
#           ...
# 3772   -36.329161
# 5191   -34.578269
# 5226    34.582117
# 5390   -34.950352
# 860     36.792711
# Name: 50_target, Length: 4933, dtype: float64

# %%
X_train = md.X_train_pcad

# %%
y_train = md.y_train

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()

# %%
y_train = sc_X.fit_transform(y_train.values.reshape(-1, 1) )

# %%
y_train
# Out:
# array([[ 1.07491251],
#        [-0.97123697],
#        [ 1.08063143],
#        ...,
#        [ 1.08575106],
#        [-0.92528869],
#        [ 1.14968654]])

# %%
import statsmodels.api as sm

# %%
X_train = sm.add_constant(X_train)
lm = sm.OLS(y_train,X_train)
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     12.45
# Date:                Thu, 06 Aug 2020   Prob (F-statistic):           8.64e-35
# Time:                        15:22:25   Log-Likelihood:                -6895.6
# No. Observations:                4933   AIC:                         1.383e+04
# Df Residuals:                    4915   BIC:                         1.394e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.765e-17      0.014   4.84e-15      1.000      -0.027       0.027
# ...

# %%
X_train = X_train.drop([6],axis=1)

# %%
lm = sm.OLS(y_train,X_train)
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     13.23
# Date:                Thu, 06 Aug 2020   Prob (F-statistic):           2.33e-35
# Time:                        15:22:39   Log-Likelihood:                -6895.6
# No. Observations:                4933   AIC:                         1.383e+04
# Df Residuals:                    4916   BIC:                         1.394e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.765e-17      0.014   4.84e-15      1.000      -0.027       0.027
# ...

# %%
X_train = X_train.drop([13],axis=1)
lm = sm.OLS(y_train,X_train)
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     14.12
# Date:                Thu, 06 Aug 2020   Prob (F-statistic):           6.06e-36
# Time:                        15:22:48   Log-Likelihood:                -6895.6
# No. Observations:                4933   AIC:                         1.382e+04
# Df Residuals:                    4917   BIC:                         1.393e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.765e-17      0.014   4.85e-15      1.000      -0.027       0.027
# ...

# %%
X_train = X_train.drop([5],axis=1)
lm = sm.OLS(y_train,X_train)
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     15.05
# Date:                Thu, 06 Aug 2020   Prob (F-statistic):           2.45e-36
# Time:                        15:23:12   Log-Likelihood:                -6896.1
# No. Observations:                4933   AIC:                         1.382e+04
# Df Residuals:                    4918   BIC:                         1.392e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.765e-17      0.014   4.85e-15      1.000      -0.027       0.027
# ...
